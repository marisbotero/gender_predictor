# %% [markdown]
# <a href="https://colab.research.google.com/github/marisbotero/gender_predictor/blob/master/gender_name_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('nombres.csv', sep =';')

# %%
data.head()
# Out:
#    nombre_1  nombre_2  genero
# 0  EMILIANO       NaN  Hombre
# 1    SALOME       NaN   Mujer
# 2   ADRIANA  PATRICIA   Mujer
# 3   ESTIVEN       NaN  Hombre
# 4     NANCY    RAQUEL   Mujer

# %%
data.drop_duplicates()
data.head()
# Out:
#    nombre_1  nombre_2  genero
# 0  EMILIANO       NaN  Hombre
# 1    SALOME       NaN   Mujer
# 2   ADRIANA  PATRICIA   Mujer
# 3   ESTIVEN       NaN  Hombre
# 4     NANCY    RAQUEL   Mujer

# %%
#data.columns
a = ['nombre_1','genero']
df = data[a]
df.head()
# Out:
#    nombre_1  genero
# 0  EMILIANO  Hombre
# 1    SALOME   Mujer
# 2   ADRIANA   Mujer
# 3   ESTIVEN  Hombre
# 4     NANCY   Mujer

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import DictVectorizer

# %%
names = df['nombre_1']

# %%
cv = CountVectorizer()
X = cv.fit_transform(names.values.astype('U'))

# %%
cv.get_feature_names()
# Out:
# ['1023561597',
#  '1096809294',
#  '98504801',
#  'aacuna',
#  'aadir',
#  'aadriana',
#  'aailen',
#  'aailyn',
#  'aakriti',
#  'aalexandra',
#  'aanisa',
#  'aaralyn',
#  'aaran',
#  'aarlon',
#  'aarom',
#  'aaron',
#  'abacuc',
#  'abad',
#  'abadesa',
#  'abadias',
#  'abadis',
#  'abaned',
#  'abanet',
#  'abbel',
#  'abbey',
#  'abbhy',
#  'abbie',
#  'abbigail',
#  'abbigayle',
#  'abbir',
#  'abby',
#  'abbygail',
#  'abda',
#  'abdala',
#  'abdel',
#  'abdelicia',
#  'abdelkader',
#  'abdelkhalek',
#  'abdelmy',
#  'abdenago',
#  'abdian',
#  'abdias',
#  'abdiel',
#  'abdiell',
#  'abdo',
#  'abdon',
#  'abdonina',
#  'abdrea',
#  'abdres',
#  'abdul',
#  'abdulio',
#  'abduval',
#  'abdy',
#  'abecbnego',
#  'abed',
#  'abel',
#  'abelardo',
#  'abelemirama',
#  'abelina',
#  'abelino',
#  'abelito',
#  'abell',
#  'abellaned',
#  'abenicio',
#  'abercio',
#  'aberlison',
#  'abertano',
#  'aberzon',
#  'abey',
#  'abgel',
#  'abhas',
#  'abi',
#  'abiath',
#  'abid',
# ...

# %%
Y = df.genero

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(x_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
model.score(x_test,y_test)
# Out:
# 0.9883926282137753

# %%
sample = ["Jose Maria"]
vector = cv.transform(sample).toarray()

# %%
model.predict(vector)
# Out:
# array(['Hombre'], dtype='<U6')
